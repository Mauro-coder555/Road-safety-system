# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
file_path = "../data/homicidios.xlsx"
df = pd.read_excel(file_path, sheet_name="HECHOS")

# %% [markdown]
# La primera intervencion sera estandarizar la escritura de todos los valores del set de datos a minúsculas para obtener consistencia, facilidad en busquedas y comparaciones. Los encabezados de las columnas se modificaran para que esten escritos completamente en mayusculas.

# %%
# Encabezados en mayúsculas
df.columns = df.columns.str.upper()

# Seleccionar solo las columnas no numéricas
columnas_no_numericas = df.select_dtypes(exclude=['number']).columns

# Aplicar la conversión a minúsculas en esas columnas
df[columnas_no_numericas] = df[columnas_no_numericas].map(lambda x: x.lower() if isinstance(x, str) else x)

# %% [markdown]
# Realizaremos el proceso de limpieza teniendo en cuenta las situaciones más comunes:
#
# 1. Datos faltantes en algunas celdas
# 2. Columnas irrelevantes (que no responden al problema que queremos resolver)
# 3. Registros (filas) repetidos
# 4. Valores extremos (*outliers*) en el caso de las variables numéricas.
#
# Al final de este proceso de limpieza deberíamos tener un set de datos **íntegro**, listo para la fase de Análisis Exploratorio.

# %%
print(df.shape)
df.head()
# Out:
# (696, 21)
#           ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA HH  \
# 0  2016-0001           1 2016-01-01  2016   1   1  04:00:00  4
# 1  2016-0002           1 2016-01-02  2016   1   2  01:15:00  1
# 2  2016-0003           1 2016-01-03  2016   1   3  07:00:00  7
# 3  2016-0004           1 2016-01-10  2016   1  10  00:00:00  0
# 4  2016-0005           1 2016-01-21  2016   1  21  05:20:00  5
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE             CALLE  \
# 0  av piedra buena y av fernandez de la cruz       avenida  piedra buena av.
# 1          av gral paz  y av de los corrales      gral paz    paz, gral. av.
# 2                         av entre rios 2034       avenida    entre rios av.
# 3      av larrazabal y gral villegas conrado       avenida    larrazabal av.
# 4  av san juan y presidente luis saenz peña        avenida      san juan av.
#
#    ALTURA                                CRUCE  \
# 0     NaN  fernandez de la cruz, f., gral. av.
# 1     NaN                  de los corrales av.
# 2  2034.0                                  NaN
# 3     NaN             villegas, conrado, gral.
# 4     NaN              saenz pe?a, luis, pres.
#
#                                DIRECCIÓN NORMALIZADA  COMUNA  \
# 0  piedra buena av. y fernandez de la cruz, f., g...       8
# 1               paz, gral. av. y de los corrales av.       9
# 2                                entre rios av. 2034       1
# 3          larrazabal av. y villegas, conrado, gral.       8
# 4            san juan av. y saenz peã‘a, luis, pres.       1
#
#                                  XY (CABA)         POS X         POS Y  \
# 0    point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1    point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2   point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3    point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4  point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
#
#     PARTICIPANTES VICTIMA    ACUSADO
# 0       moto-auto    moto       auto
# 1  auto-pasajeros    auto  pasajeros
# 2       moto-auto    moto       auto
# 3         moto-sd    moto         sd
# 4  moto-pasajeros    moto  pasajeros

# %%
duplicados_totales = df.duplicated().sum()
duplicados_totales
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   N_VICTIMAS             696 non-null    int64
#  2   FECHA                  696 non-null    datetime64[ns]
#  3   AAAA                   696 non-null    int64
#  4   MM                     696 non-null    int64
#  5   DD                     696 non-null    int64
#  6   HORA                   696 non-null    object
#  7   HH                     696 non-null    object
#  8   LUGAR_DEL_HECHO        696 non-null    object
#  9   TIPO_DE_CALLE          696 non-null    object
#  10  CALLE                  695 non-null    object
#  11  ALTURA                 129 non-null    float64
#  12  CRUCE                  525 non-null    object
#  13  DIRECCIÓN NORMALIZADA  688 non-null    object
#  14  COMUNA                 696 non-null    int64
#  15  XY (CABA)              696 non-null    object
#  16  POS X                  696 non-null    object
#  17  POS Y                  696 non-null    object
#  18  PARTICIPANTES          696 non-null    object
#  19  VICTIMA                696 non-null    object
#  20  ACUSADO                696 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(14)
# memory usage: 114.3+ KB

# %% [markdown]
# Los datos no están completos, pues no todas las columnas tienen la misma cantidad de registros.
#
# El número total de registros debería ser 696. Sin embargo las columnas "Altura", "Cruce", "Dirección Normalizada" y "Calle" tienen datos faltantes.
#
# Por ser un set de datos reducido, optaremos por imputar las filas correspondientes.

# %% [markdown]
# Revisaremos en primer lugar los registros faltantes en "Calle" y "Dirección Normalizada" para ver que ocurre en esos casos, considerando que es una cantidad pequeña.

# %%
# Filtrar registros donde la columna "Calle" es nula
calle_nula = df[df['CALLE'].isnull()]

# Filtrar registros donde la columna "Direccion normalizada" es nula
direccion_nula = df[df['DIRECCIÓN NORMALIZADA'].isnull()]

# %%
calle_nula
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 119  2016-0151           1 2016-11-18  2016  11  18  20:35:00  20
#
#     LUGAR_DEL_HECHO TIPO_DE_CALLE CALLE  ALTURA CRUCE DIRECCIÓN NORMALIZADA  \
# 119              sd         calle   NaN     NaN   NaN                   NaN
#
#      COMUNA    XY (CABA) POS X POS Y PARTICIPANTES VICTIMA ACUSADO
# 119       0  point (. .)     .     .     peaton-sd  peaton      sd

# %% [markdown]
# Al ser solo un registro que cuenta con varios campos sin especificar, se decide eliminarlo del dataset

# %%
df = df[df['ID'] != '2016-0151']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 695 entries, 0 to 695
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     695 non-null    object
#  1   N_VICTIMAS             695 non-null    int64
#  2   FECHA                  695 non-null    datetime64[ns]
#  3   AAAA                   695 non-null    int64
#  4   MM                     695 non-null    int64
#  5   DD                     695 non-null    int64
#  6   HORA                   695 non-null    object
#  7   HH                     695 non-null    object
#  8   LUGAR_DEL_HECHO        695 non-null    object
#  9   TIPO_DE_CALLE          695 non-null    object
#  10  CALLE                  695 non-null    object
#  11  ALTURA                 129 non-null    float64
#  12  CRUCE                  525 non-null    object
#  13  DIRECCIÓN NORMALIZADA  688 non-null    object
#  14  COMUNA                 695 non-null    int64
#  15  XY (CABA)              695 non-null    object
#  16  POS X                  695 non-null    object
#  17  POS Y                  695 non-null    object
#  18  PARTICIPANTES          695 non-null    object
#  19  VICTIMA                695 non-null    object
#  20  ACUSADO                695 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(14)
# memory usage: 119.5+ KB

# %%
direccion_nula
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 38   2016-0052           1 2016-04-20  2016   4  20  20:00:00  20
# 106  2016-0136           1 2016-10-25  2016  10  25  00:00:00   0
# 119  2016-0151           1 2016-11-18  2016  11  18  20:35:00  20
# 180  2017-0050           2 2017-04-28  2017   4  28  11:08:08  11
# 181  2017-0051           1 2017-05-01  2017   5   1  03:47:47   3
# 313  2018-0039           1 2018-04-21  2018   4  21  22:15:00  22
# 546  2020-0026           1 2020-05-17  2020   5  17  06:40:00   6
# 621  2021-0023           1 2021-03-01  2021   3   1  09:20:00   9
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  \
# 38                autopista lugones pk 10000     autopista
# 106         au buenos aires - la plata km. 4     autopista
# 119                                       sd         calle
# 180  au perito moreno y ramal enlace au1/au6     autopista
# 181                       au dellepiane 2400     autopista
# 313                 autopista lugones km 4.7     autopista
# 546             lugones, leopoldo av. km 6,1     autopista
# 621         au buenos aires la plata  km 4,5     autopista
#
#                                     CALLE  ALTURA CRUCE DIRECCIÓN NORMALIZADA  \
# 38                  lugones, leopoldo av.     NaN   NaN                   NaN
# 106     autopista buenos aires - la plata     NaN   NaN                   NaN
# 119                                   NaN     NaN   NaN                   NaN
# 180               autopista perito moreno     NaN   NaN                   NaN
# 181  autopista dellepiane luis tte. gral.     NaN   NaN                   NaN
# 313                 lugones, leopoldo av.     NaN   NaN                   NaN
# 546                 lugones, leopoldo av.     NaN   NaN                   NaN
# 621     autopista buenos aires - la plata     NaN   NaN                   NaN
#
#      COMUNA    XY (CABA) POS X POS Y     PARTICIPANTES VICTIMA      ACUSADO
# 38       13  point (. .)     .     .           moto-sd    moto           sd
# 106       4  point (. .)     .     .       moto-cargas    moto       cargas
# 119       0  point (. .)     .     .         peaton-sd  peaton           sd
# 180       9  point (. .)     .     .       moto-cargas    moto       cargas
# 181       7  point (. .)     .     .         auto-auto    auto         auto
# 313      14  point (. .)     .     .       peaton-auto  peaton         auto
# 546      14  point (. .)     .     .  moto-objeto fijo    moto  objeto fijo
# 621       4  point (. .)     .     .       moto-cargas    moto       cargas

# %% [markdown]
# Notamos que todos los datos asociados a la ubicación no estan presentes en estos registros, por lo que se decide imputar como "sin datos", y tomar la columna Altura como un string ya que no tiene un sentido numérico continuo.

# %%
# Convertir la columna 'Altura' a tipo de dato string
# Convertir la columna 'Altura' a tipo de dato string y reemplazar NaN por 'None'
df['ALTURA'] = df['ALTURA'].astype(str).replace('nan', None)

# Imputación para Altura en registros con Dirección Normalizada nula
df.loc[df['DIRECCIÓN NORMALIZADA'].isnull(), 'ALTURA'] = 'sin datos'

# Imputación para Cruce en registros con Dirección Normalizada nula
df.loc[df['DIRECCIÓN NORMALIZADA'].isnull(), 'CRUCE'] = 'sin datos'

# Imputación para XY (CABA) en registros con Dirección Normalizada nula
df.loc[df['DIRECCIÓN NORMALIZADA'].isnull(), 'XY (CABA)'] = 'sin datos'

# Imputación para pos x y pos y en registros con Dirección Normalizada nula
df.loc[df['DIRECCIÓN NORMALIZADA'].isnull(), 'POS X'] = 'sin datos'
df.loc[df['DIRECCIÓN NORMALIZADA'].isnull(), 'POS Y'] = 'sin datos'

# Imputación para Dirección Normalizada
df['DIRECCIÓN NORMALIZADA'].fillna('sin datos', inplace=True)

# %% [markdown]
# Se verifica la ausencia de registros con datos asociados a la direccion nulos, ya que fueron imputados.

# %%
direccion_nula = df[df['DIRECCIÓN NORMALIZADA'].isnull()]
direccion_nula
# Out:
# Empty DataFrame
# Columns: [ID, N_VICTIMAS, FECHA, AAAA, MM, DD, HORA, HH, LUGAR_DEL_HECHO, TIPO_DE_CALLE, CALLE, ALTURA, CRUCE, DIRECCIÓN NORMALIZADA, COMUNA, XY (CABA), POS X, POS Y, PARTICIPANTES, VICTIMA, ACUSADO]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 695 entries, 0 to 695
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     695 non-null    object
#  1   N_VICTIMAS             695 non-null    int64
#  2   FECHA                  695 non-null    datetime64[ns]
#  3   AAAA                   695 non-null    int64
#  4   MM                     695 non-null    int64
#  5   DD                     695 non-null    int64
#  6   HORA                   695 non-null    object
#  7   HH                     695 non-null    object
#  8   LUGAR_DEL_HECHO        695 non-null    object
#  9   TIPO_DE_CALLE          695 non-null    object
#  10  CALLE                  695 non-null    object
#  11  ALTURA                 136 non-null    object
#  12  CRUCE                  532 non-null    object
#  13  DIRECCIÓN NORMALIZADA  695 non-null    object
#  14  COMUNA                 695 non-null    int64
#  15  XY (CABA)              695 non-null    object
#  16  POS X                  695 non-null    object
#  17  POS Y                  695 non-null    object
#  18  PARTICIPANTES          695 non-null    object
#  19  VICTIMA                695 non-null    object
#  20  ACUSADO                695 non-null    object
# dtypes: datetime64[ns](1), int64(5), object(15)
# memory usage: 119.5+ KB

# %% [markdown]
# Ahora nos falta revisar un poco mas como tratar las columnas "Altura" y "Cruce". Al sumar las cantidades de no nulos en estas dos columnas (136 + 532 = 668) nos permite pensar que podria estar ocurriendo que para cuando una "Altura" no esta definida, es porque el hecho fue en un "Cruce" de calles y viceversa. Sin embargo revisaremos los valores donde no estan definidas "Cruce" y "Altura" simultaneamente.

# %%
cruce_altura_nulos = df.loc[(df['CRUCE'].isnull()) & (df['ALTURA'].isnull())]
cruce_altura_nulos
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 35   2016-0049           1 2016-04-17  2016   4  17  00:00:00   0
# 64   2016-0087           1 2016-07-02  2016   7   3  00:10:00   0
# 71   2016-0096           1 2016-07-25  2016   7  25  07:00:00   7
# 81   2016-0107           1 2016-08-20  2016   8  20  08:22:00   8
# 91   2016-0118           1 2016-09-04  2016   9   4  03:30:00   3
# 100  2016-0130           1 2016-10-04  2016  10   4  12:30:00  12
# 127  2016-0160           1 2016-12-06  2016  12   6  05:30:00   5
# 139  2016-0174           1 2016-12-27  2016  12  27  00:00:00   0
# 148  2017-0009           1 2017-01-16  2017   1  16  13:56:00  13
# 155  2017-0016           1 2017-02-03  2017   2   3  05:12:21   5
# 176  2017-0042           1 2017-04-10  2017   4  10  09:00:00   9
# 234  2017-0112           2 2017-09-10  2017   9  10  09:32:17   9
# 256  2017-0140           1 2017-11-19  2017  11  19  23:22:17  23
# 281  2018-0007           1 2018-01-11  2018   1  11  02:30:00   2
# 294  2018-0020           1 2018-02-19  2018   2  19  22:00:00  22
# 346  2018-0072           1 2018-07-11  2018   7  11  13:15:00  13
# 385  2018-0111           1 2018-10-19  2018  10  19  12:13:00  12
# 398  2018-0124           1 2018-11-15  2018  11  15  19:40:00  19
# 474  2019-0058           1 2019-07-10  2019   7  10  09:20:00   9
# 492  2019-0076           1 2019-09-05  2019   9   5  18:00:00  18
# 511  2019-0095           1 2019-11-20  2019  11  20  15:30:00  15
# 513  2019-0097           1 2019-11-25  2019  11  25  08:50:00   8
# 555  2020-0035           1 2020-08-04  2020   8   4  05:30:00   5
# 559  2020-0039           1 2020-09-01  2020   9   1  19:17:42  19
# 585  2020-0066           1 2020-12-07  2020  12   7  04:30:00   4
# 599  2021-0001           1 2021-01-06  2021   1   6  18:00:00  18
# 601  2021-0003           1 2021-01-10  2021   1  10  07:40:00   7
# 624  2021-0026           1 2021-03-15  2021   3  15  02:35:00   2
# 631  2021-0033           1 2021-04-14  2021   4  14  17:50:00  17
# 643  2021-0045           1 2021-05-26  2021   5  26  17:24:00  17
# 655  2021-0057           1 2021-07-10  2021   7  10  23:30:00  23
# 665  2021-0067           1 2021-08-08  2021   8   8  09:29:00   9
# 679  2021-0081           1 2021-11-02  2021  11   2  13:35:00  13
# 680  2021-0082           1 2021-11-06  2021  11   6  04:39:00   4
#
#                                        LUGAR_DEL_HECHO TIPO_DE_CALLE  \
# 35   autopista 1 sur presidente arturo frondizi km....     autopista
# 64    autopista 1 sur pte arturo frondizi y av caseros     autopista
# 71        autopista dellepiane luis tte. gral. km. 2,3     autopista
# 81             autopista 9 de julio sur alt av mendoza     autopista
# 91          autopista 1 sur pte arturo frondizi km 2.9     autopista
# 100               autopista 9 de julio sur y av brasil     autopista
# 127                autopista perito moreno altura velz     autopista
# 139                               autopista 25 de mayo     autopista
# 148                          au 25 de mayo y av. boedo     autopista
# 155  au 25 de mayo, kilometro 8.3, sentido hacia pr...     autopista
# 176                      av. leopoldo lugones pkm 6900      gral paz
# 234                         au 25 de mayo y av. varela     autopista
# 256                        au arturo frondizi pkm 3100     autopista
# 281                           au perito moreno  km 0.6     autopista
# 294   fernandez de la cruz subida au héctor j. cámpora     autopista
# 346  au dellepiane kilometro 0.0, altura calle mont...     autopista
# 385    au perito moreno y av. eva perón sentido centro     autopista
# 398          au perito moreno y reservistas argentinos     autopista
# 474  autopista perito moreno altura paso a nivel de...     autopista
# 492  autopista 1 sur presidente arturo frondizi alt...     autopista
# 511  autopista 1 sur presidente arturo frondizi alt...     autopista
# 513                     autopista perito moreno km 5,6     autopista
# 555  au 25 de mayo altura pumacahua y recuero, casi...     autopista
# 559                                    murguiondo 2700         calle
# 585  autopista perito moreno altura estacion de tre...     autopista
# 599                                  au frondizi km. 3     autopista
# 601                              au 25 de mayo km. 3,7     autopista
# 624        au frondizi altura quinquela martin, benito     autopista
# 631              au 25 de mayo altura bajada boedo av.     autopista
# 643                           au frondizi y suarez av.     autopista
# 655           au illia km 3.2, altura cabinas de peaje     autopista
# 665                 au frondizi km 2,9 (altura brasil)     autopista
# 679                        au frondizi subida brandsen     autopista
# 680                   au 25 de mayo km7 (altura pasco)     autopista
#
#                                           CALLE ALTURA CRUCE  \
# 35   autopista 1 sur presidente arturo frondizi   None   NaN
# 64   autopista 1 sur presidente arturo frondizi   None   NaN
# 71         autopista dellepiane luis tte. gral.   None   NaN
# 81   autopista 1 sur presidente arturo frondizi   None   NaN
# 91   autopista 1 sur presidente arturo frondizi   None   NaN
# 100  autopista 1 sur presidente arturo frondizi   None   NaN
# 127                     autopista perito moreno   None   NaN
# 139                        autopista 25 de mayo   None   NaN
# 148                        autopista 25 de mayo   None   NaN
# 155                        autopista 25 de mayo   None   NaN
# 176                       lugones, leopoldo av.   None   NaN
# 234                        autopista 25 de mayo   None   NaN
# 256  autopista 1 sur presidente arturo frondizi   None   NaN
# 281                     autopista perito moreno   None   NaN
# 294      autopista presidente hector j. campora   None   NaN
# 346        autopista dellepiane luis tte. gral.   None   NaN
# 385                     autopista perito moreno   None   NaN
# 398                     autopista perito moreno   None   NaN
# 474                     autopista perito moreno   None   NaN
# 492  autopista 1 sur presidente arturo frondizi   None   NaN
# 511  autopista 1 sur presidente arturo frondizi   None   NaN
# 513                     autopista perito moreno   None   NaN
# 555                        autopista 25 de mayo   None   NaN
# 559                                  murguiondo   None   NaN
# 585                     autopista perito moreno   None   NaN
# 599  autopista 1 sur presidente arturo frondizi   None   NaN
# 601                        autopista 25 de mayo   None   NaN
# 624  autopista 1 sur presidente arturo frondizi   None   NaN
# 631                        autopista 25 de mayo   None   NaN
# 643  autopista 1 sur presidente arturo frondizi   None   NaN
# 655                      autopista arturo illia   None   NaN
# 665  autopista 1 sur presidente arturo frondizi   None   NaN
# 679  autopista 1 sur presidente arturo frondizi   None   NaN
# 680                        autopista 25 de mayo   None   NaN
#
#                                  DIRECCIÓN NORMALIZADA  COMUNA  \
# 35          autopista 1 sur presidente arturo frondizi       4
# 64   autopista 1 sur presidente arturo frondizi y c...       1
# 71                autopista dellepiane luis tte. gral.       8
# 81   autopista 1 sur presidente arturo frondizi y d...       4
# 91   autopista 1 sur presidente arturo frondizi km....       1
# 100  autopista 1 sur presidente arturo frondizi y b...       1
# 127   autopista perito moreno (altura velez sarsfield)       9
# 139                               autopista 25 de mayo       0
# 148                   autopista 25 de mayo y boedo av.       5
# 155                       autopista 25 de mayo km. 8.3       1
# 176                              lugones, leopoldo av.      14
# 234                  autopista 25 de mayo y varela av.       7
# 256         autopista 1 sur presidente arturo frondizi       4
# 281                    autopista perito moreno km. 0.6       9
# 294  fernandez de la cruz f., gral. av. y autopista...       8
# 346     autopista dellepiane luis tte. gral. y montiel       8
# 385          autopista perito moreno & peron, eva  av.       9
# 398   autopista perito moreno y reservistas argentinos       9
# 474                 autopista perito moreno e irigoyen      10
# 492  autopista 1 sur presidente arturo frondizi y d...       4
# 511  autopista 1 sur presidente arturo frondizi y c...       1
# 513                    autopista perito moreno km. 5.6       9
# 555                   autopista 25 de mayo y pumacahua       7
# 559                                         murguiondo       9
# 585  autopista perito moreno (altura estacion de tr...      10
# 599                                  au frondizi km. 3       1
# 601                       autopista 25 de mayo km. 3.7       7
# 624  autopista 1 sur presidente arturo frondizi y q...       4
# 631                   autopista 25 de mayo y boedo av.       5
# 643  autopista 1 sur presidente arturo frondizi y s...       4
# 655          autopista  arturo illia (cabina de peaje)       2
# 665  autopista 1 sur presidente arturo frondizi y b...       1
# 679  autopista 1 sur presidente arturo frondizi y b...       4
# 680                       autopista 25 de mayo y pasco       3
#
#                                    XY (CABA)               POS X  \
# 35                               point (. .)  -58.37714647568196
# 64   point (107762.62066736 100018.90176187)        -58.37864583
# 71                               point (. .)  -58.47433193007387
# 81    point (108408.31858686 97219.56218484)        -58.37157668
# 91   point (107696.68171812 100254.76268710)        -58.37936704
# 100  point (107720.24059557 100176.85101454)        -58.37910942
# 127    point (94867.91408532 99212.26216105)        -58.51927194
# 139                              point (. .)                   .
# 148   point (104341.1368196 100202.74363294)        -58.41595919
# 155  point (107547.76713701 100705.57738660)        -58.38099494
# 176                              point (. .)                   .
# 234   point (100479.14412395 98812.52258620)        -58.45807401
# 256                              point (. .)                   .
# 281    point (94340.14761734 99250.24722124)        -58.52502765
# 294   point (101207.19032483 96015.90575056)        -58.45012957
# 346    point (98224.62123059 93867.97738800)        -58.48267426
# 385    point (99423.87045126 97756.09331484)        -58.46958442
# 398    point (94668.77734942 99160.32825286)        -58.52144411
# 474    point (96064.06591151 99221.69236283)        -58.50622631
# 492   point (108408.31866027 97219.56223456)        -58.37157668
# 511  point (107762.62066755 100018.90176184)        -58.37864583
# 513    point (98724.36593359 97905.39654686)        -58.47721439
# 555   point (101156.55025059 99210.16912341)        -58.45068621
# 559                              point (. .)                   .
# 585    point (96471.01552298 99259.49298489)        -58.50178784
# 599  point (107674.71781880 100334.26713627)        -58.37960727
# 601   point (103005.63484321 99983.28177809)        -58.43052224
# 624   point (108038.11136985 98307.74373426)        -58.37562539
# 631  point (104341.13684161 100202.74307433)        -58.41595919
# 643   point (107903.91828587 98767.43091425)        -58.37709334
# 655  point (106489.89755339 105947.16700228)        -58.39257023
# 665  point (107720.23994349 100176.85080944)        -58.37910943
# 679   point (107979.30419282 99027.13636949)        -58.37627355
# 680  point (106179.07517962 100523.29161457)        -58.39591856
#
#                   POS Y       PARTICIPANTES VICTIMA      ACUSADO
# 35   -34.63657525428238               sd-sd      sd           sd
# 64         -34.62907067    moto-objeto fijo    moto  objeto fijo
# 71   -34.66684950051973         moto-cargas    moto       cargas
# 81         -34.65429986           moto-auto    moto         auto
# 91         -34.62694503           auto-auto    auto         auto
# 100        -34.62764717         moto-cargas    moto       cargas
# 127        -34.63635787  cargas-objeto fijo  cargas  objeto fijo
# 139                   .               sd-sd      sd           sd
# 148        -34.62743346         moto-cargas    moto       cargas
# 155        -34.62288231         moto-cargas    moto       cargas
# 176                   .         moto-cargas    moto       cargas
# 234        -34.63997430    auto-objeto fijo    auto  objeto fijo
# 256                   .      moto-pasajeros    moto    pasajeros
# 281        -34.63601265           auto-auto    auto         auto
# 294        -34.66518343         moto-cargas    moto       cargas
# 346        -34.68454456         moto-cargas    moto       cargas
# 385        -34.64949724         moto-cargas    moto       cargas
# 398        -34.63682499       cargas-cargas  cargas       cargas
# 474        -34.63627822      moto-pasajeros    moto    pasajeros
# 492        -34.65429986         moto-cargas    moto       cargas
# 511        -34.62907067         moto-cargas    moto       cargas
# 513        -34.64815069            multiple    moto     multiple
# 555        -34.63638927      moto-pasajeros    moto    pasajeros
# 559                   .       peaton-cargas  peaton       cargas
# 585        -34.63593897    moto-objeto fijo    moto  objeto fijo
# 599        -34.62622851           moto-auto    moto         auto
# 601        -34.62941648    moto-objeto fijo    moto  objeto fijo
# 624        -34.64449357    moto-objeto fijo    moto  objeto fijo
# 631        -34.62743346    auto-objeto fijo    auto  objeto fijo
# 643        -34.64035082            multiple    moto     multiple
# 655        -34.57563957    auto-objeto fijo    auto  objeto fijo
# 665        -34.62764718    moto-objeto fijo    moto  objeto fijo
# 679        -34.63800916         moto-cargas    moto       cargas
# 680        -34.62453459           moto-auto    moto         auto

# %% [markdown]
# Observamos que los casos en los que la altura y la calle no estan definidas simultaneamente, pero en la mayoria de los casos tenemos informacion de la pos x y pos y por separado. Tambien hay algunos casos donde la posicion no esta definida en ninguna parte. Finalmente optamos por imputar todos los casos por "sin dato" ya que aun sin esa información especificada, los registros contienen otros valores que pueden ser utiles para otros analisis como el nombre y tipo de calle

# %%
df['CRUCE'].fillna('sin datos', inplace=True)
df['ALTURA'].fillna('sin datos', inplace=True)

# %% [markdown]
# Ya no tenemos nulos en nuestro set de datos

# %%
cruce_altura_nulos = df.loc[(df['CRUCE'].isnull()) & (df['ALTURA'].isnull())]
cruce_altura_nulos
# Out:
# Empty DataFrame
# Columns: [ID, N_VICTIMAS, FECHA, AAAA, MM, DD, HORA, HH, LUGAR_DEL_HECHO, TIPO_DE_CALLE, CALLE, ALTURA, CRUCE, DIRECCIÓN NORMALIZADA, COMUNA, XY (CABA), POS X, POS Y, PARTICIPANTES, VICTIMA, ACUSADO]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 695 entries, 0 to 695
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     695 non-null    object
#  1   N_VICTIMAS             695 non-null    int64
#  2   FECHA                  695 non-null    datetime64[ns]
#  3   AAAA                   695 non-null    int64
#  4   MM                     695 non-null    int64
#  5   DD                     695 non-null    int64
#  6   HORA                   695 non-null    object
#  7   HH                     695 non-null    object
#  8   LUGAR_DEL_HECHO        695 non-null    object
#  9   TIPO_DE_CALLE          695 non-null    object
#  10  CALLE                  695 non-null    object
#  11  ALTURA                 695 non-null    object
#  12  CRUCE                  695 non-null    object
#  13  DIRECCIÓN NORMALIZADA  695 non-null    object
#  14  COMUNA                 695 non-null    int64
#  15  XY (CABA)              695 non-null    object
#  16  POS X                  695 non-null    object
#  17  POS Y                  695 non-null    object
#  18  PARTICIPANTES          695 non-null    object
#  19  VICTIMA                695 non-null    object
#  20  ACUSADO                695 non-null    object
# dtypes: datetime64[ns](1), int64(5), object(15)
# memory usage: 119.5+ KB

# %% [markdown]
# En la columna "Participantes" ocurre algo particular. Estan los datos de dos participantes separados por guión medio. Esto pudimos verlo en impresiones del dataframe *cruce_altura_nulos*. Para mayor comodidad y poder utilizar esta informacion mas facilmente en gráficos, separaremos estos datos en 2 columnas. "Participante A" y "Participante B"

# %%
# Dividir la columna 'Participantes' en dos nuevas columnas
df[['PARTICIPANTE A', 'PARTICIPANTE B']] = df['PARTICIPANTES'].str.split('-', n=1, expand=True)

# Eliminar la columna 'Participantes'
df.drop('PARTICIPANTES', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['ID', 'N_VICTIMAS', 'FECHA', 'AAAA', 'MM', 'DD', 'HORA', 'HH',
#        'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE', 'CALLE', 'ALTURA', 'CRUCE',
#        'DIRECCIÓN NORMALIZADA', 'COMUNA', 'XY (CABA)', 'POS X', 'POS Y',
#        'VICTIMA', 'ACUSADO', 'PARTICIPANTE A', 'PARTICIPANTE B'],
#       dtype='object')

# %% [markdown]
# Ya no tenemos nulos en nuestro set de datos y dividimos la columna "Participantes", pero aun queda estandarizar las imputaciones de valores, ya que por defecto, cuando no hay datos viene rellenado como "sd".

# %%
df.replace('sd', 'sin datos', inplace=True)

# %% [markdown]
# Se observó que la columna "LUGAR_DEL_HECHO" contiene una combinacion de la información de las columnas "Altura", "Cruce", "Calle" y en ocasiones alguna información extra no muy relevante que incluye numeros y "km". Se decide eliminar esta columna ya que para los fines del proyecto se desean los datos separados para poder evaluar relaciones y hacer interpretaciones.

# %%
df = df.drop('LUGAR_DEL_HECHO', axis=1)

# %% [markdown]
# Ahora revisaremos las 3 columnas dedicadas a posición, "XY (CABA)" y "pos x" / "pos y". En el primer caso tenemos geocodificacion plana, y en el segundo (las columnas de pos x y pos y) tenemos el sistema wgs84. Se verá cual tiene mayor cantidad de informacion, y si ocurre que una tiene informacion y la otra no.

# %% [markdown]
# Primero imputaremos los datos con "sin dato". Notamos que cuando no hay informacion, en XY (CABA) se ve "point(. .)", mientras que en las otras dos columnas se rellenan con "." puntos.

# %%
df['XY (CABA)'] = df['XY (CABA)'].replace('point (. .)', 'sin datos')
df['POS X'] = df['POS X'].replace('.', 'sin datos')
df['POS Y'] = df['POS Y'].replace('.', 'sin datos')

# %%
# Contar cuando 'XY (CABA)' tiene datos y 'pos x' y 'pos y' están ambos sin datos
conteo_datos_faltantes = df.apply(lambda x: ('sin datos' in x['POS X'] and 'sin datos' in x['POS Y'] and 'sin datos' not in x['XY (CABA)']), axis=1).value_counts()

# %%
conteo_datos_faltantes
# Out:
# False    695
# Name: count, dtype: int64

# %%
# Contar cuando 'pos x' y 'pos y' tienen datos y 'XY (CABA)' está sin datos
conteo_datos_presentes = df.apply(lambda x: ('sin datos' in x['XY (CABA)'] and 'sin datos' not in x['POS X'] and 'sin datos' not in x['POS Y']), axis=1).value_counts()

# %%
conteo_datos_presentes
# Out:
# False    693
# True       2
# Name: count, dtype: int64

# %% [markdown]
# Como observamos, hay 2 casos en los que la columna XY (CABA) no tiene datos, pero la pos x y pos y si tienen. Se decide eliminar la primer columna y trabajar entonces con las columnas en geocodificacion wgs84

# %%
# Eliminar la columna 'XY (CABA)'
df = df.drop(columns=['XY (CABA)'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 695 entries, 0 to 695
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     695 non-null    object
#  1   N_VICTIMAS             695 non-null    int64
#  2   FECHA                  695 non-null    datetime64[ns]
#  3   AAAA                   695 non-null    int64
#  4   MM                     695 non-null    int64
#  5   DD                     695 non-null    int64
#  6   HORA                   695 non-null    object
#  7   HH                     695 non-null    object
#  8   TIPO_DE_CALLE          695 non-null    object
#  9   CALLE                  695 non-null    object
#  10  ALTURA                 695 non-null    object
#  11  CRUCE                  695 non-null    object
#  12  DIRECCIÓN NORMALIZADA  695 non-null    object
#  13  COMUNA                 695 non-null    int64
#  14  POS X                  695 non-null    object
#  15  POS Y                  695 non-null    object
#  16  VICTIMA                695 non-null    object
#  17  ACUSADO                695 non-null    object
#  18  PARTICIPANTE A         695 non-null    object
#  19  PARTICIPANTE B         678 non-null    object
# dtypes: datetime64[ns](1), int64(5), object(14)
# memory usage: 114.0+ KB

# %% [markdown]
# Finalmente tenemos nuestro set de datos limpio, sin nulos ni duplicados. Los valores faltantes fueron imputados y se han eliminado columnas innecesarias.

# %%
df.to_csv('../data/homicidios_clean.csv', index=False)
